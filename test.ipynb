# %% [markdown]
# <a href="https://colab.research.google.com/github/miss-dd/colab-projects/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm

x = np.array([1, 2, 3, 4, 5])
y = np.array([7, 14, 15, 18, 19])

n = np.size(x)
x_mean = np.mean(x)
y_mean = np.mean(y)

print(x_mean, y_mean)

Sxy = np.sum(x * y) - n * x_mean * y_mean
Sxx = np.sum(x * x) - n * x_mean * x_mean

# Find the slope b1: Sxy / Sxx
b1 = Sxy / Sxx
# find the y-intercept b0: y_mean - b1 * x_mean
b0  = y_mean - b1 * x_mean

print("The slope b1 is: ", b1)
print('The y-intercept b0 is: ', b0)

# define the linear model equation using the slope and y-intercept
y_pred = b0 + b1 * x
plt.scatter(x, y, color = 'red')
plt.plot(x, y_pred, color = 'green')
plt.xlabel('Independent variables X')
plt.ylabel('Dependent variables Y')
# Out:
# 3.0 14.6
# The slope b1 is:  2.8
# The y-intercept b0 is:  6.200000000000001
# Text(0, 0.5, 'Dependent variables Y')

# %%
# analyze the performance of the linear regression model using the mse and r2
error = y - y_pred
se = np.sum(error ** 2)
mse = se / n

print('The mse is: ', mse)

if(mse < 1 and mse > 0):
  {
    print("The cost function (mse) is minimum and has a good perfomance")
}
else:
    print("The cost function is high, poor performance bcz the predicted values is not close to the actual values")


# find the r2: 1 - se / sst
# sst means sum of square totals
sst = np.sum((y-y_mean) ** 2)
r2 = 1 - (se / sst)
print(r2)

# I'm now going to learn the interpretivity of the graph
# will come back to this later after i'm done with learning logistics regression
# then will apply the interpretivity of model performance on both
# this is a recap of what i learn and understood from saturday
# Out:
# The mse is:  2.160000000000001
# The cost function is high, poor performance bcz the predicted values is not close to the actual values
# 0.8789237668161435
